# %% [markdown]
# <a href="https://colab.research.google.com/github/GianTheGoat/project_gss/blob/main/Project1_draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project: GSS
#
# **Group 2: Randa Ampah, Neha Channamraju, Rebekah Weaver, Faith Koobial, Gian Baez, Aysha Hussen**

# %% [markdown]
# # Summary

# %% [markdown]
# # Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

gss = pd.read_parquet("https://github.com/DS3001/project_gss/raw/main/gss_chunk_3.parquet")
gss = gss.dropna(how = "all")

filt = gss.filter(items = ["year", "occ" "wrkstat", "wrkslf", "hrs1", "income06",
                           "degree", "marital", "happy", "partyid"],axis=1)
yrgss = filt[(filt["year"] == 2006) | (filt["year"] == 2008) | (filt["year"] == 2010)]
yrgss
# Out:
#       year        wrkslf  hrs1            income06       degree  \
# 0     2006  someone else  40.0  $110000 to $129999  high school
# 1     2006  someone else   NaN    $75000 to $89999   bachelor's
# 2     2006  someone else  35.0     $60000 to 74999   bachelor's
# 3     2006  someone else  50.0     $35000 to 39999  high school
# 4     2006  someone else  40.0    $75000 to $89999   bachelor's
# ...    ...           ...   ...                 ...          ...
# 6822  2010  someone else   NaN     $150000 or over   bachelor's
# 6823  2010  someone else   NaN     $12500 to 14999  high school
# 6824  2010  someone else  40.0     $20000 to 22499  high school
# 6825  2010  someone else  49.0     $6 000 to 6 999   bachelor's
# 6826  2010  someone else  40.0     $35000 to 39999  high school
#
#             marital          happy                             partyid
# 0           married            NaN  independent (neither, no response)
# 1     never married   pretty happy  independent (neither, no response)
# 2          divorced   pretty happy          not very strong republican
# 3     never married            NaN          not very strong republican
# 4           married     very happy          not very strong republican
# ...             ...            ...                                 ...
# 6822        married   pretty happy                   strong republican
# 6823        widowed  not too happy                   strong republican
# 6824      separated     very happy            not very strong democrat
# 6825       divorced   pretty happy  independent (neither, no response)
# 6826  never married   pretty happy                         other party
#
# [6827 rows x 8 columns]

# %% [markdown]
# # Results

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Appendix
